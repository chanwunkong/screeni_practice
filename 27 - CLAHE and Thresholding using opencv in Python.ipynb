# %% [markdown]
# 27 - CLAHE and Thresholding using opencv in Python
# 1.  Threshold
# 2.  OTSU

# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')
path = r'/content/gdrive/My Drive/Colab Notebooks/screeni_practice'
os.chdir( path )
# Out:
# Mounted at /content/gdrive

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('images/Alloy.jpg', 0)
eq_img = cv2.equalizeHist(img)

plt.hist(eq_img.flat, bins=100, range=(0,255))

clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
cl_img = clahe.apply(img)

cv2_imshow(img)
cv2_imshow(eq_img)
cv2_imshow(cl_img)
# Out:
# <PIL.Image.Image image mode=L size=694x484 at 0x7FC25A7B7E80>
# <PIL.Image.Image image mode=L size=694x484 at 0x7FC25A379310>
# <PIL.Image.Image image mode=L size=694x484 at 0x7FC25A7B7E80>

# %%
plt.hist(cl_img.flat, bins=100, range=(100,255))

ret, thresh1 = cv2.threshold(cl_img, 190, 150, cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(cl_img, 190, 255, cv2.THRESH_BINARY_INV)

cv2_imshow(img)
cv2_imshow(thresh1)
cv2_imshow(thresh2)
# Out:
# <PIL.Image.Image image mode=L size=694x484 at 0x7FC24DDFC4F0>
# <PIL.Image.Image image mode=L size=694x484 at 0x7FC25AD00790>
# <PIL.Image.Image image mode=L size=694x484 at 0x7FC24DDFC3D0>

# %%
ret2, thresh3 = cv2.threshold(cl_img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
# ret2 auto
cv2_imshow(thresh3)
print(ret2)
# Out:
# <PIL.Image.Image image mode=L size=694x484 at 0x7FC25A9EF760>
# 181.0
