# %% [markdown]
# 25 - Reading Images, Splitting Channels, Resizing using openCV in Python
# 1.  Reading Images
# 2.  Splitting, Merging Channels
# 3.  Resizing

# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')
path = r'/content/gdrive/My Drive/Colab Notebooks/screeni_practice'
os.chdir( path )
# Out:
# Mounted at /content/gdrive

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('images/RGBY.jpg')
print(img.shape)
img = cv2.imread('images/RGBY.jpg', 0)
print(img.shape)
img = cv2.imread('images/RGBY.jpg', 1)
print(img.shape)
img = cv2.imread('images/RGBY.jpg', 2)
print(img.shape)
# Out:
# (586, 415, 3)
# (586, 415)
# (586, 415, 3)
# (586, 415)

# %%
# openCV BGR
img = cv2.imread('images/RGBY.jpg')
print('Tope Left', img[0,0])
print('Tope Right', img[0,400])
print('Bottom Left', img[580,0])
print('Bottom Right', img[580,400])
# Out:
# Tope Left [38  3  0]
# Tope Right [ 0 20 21]
# Bottom Left [ 0 55  0]
# Bottom Right [ 16   6 250]

# %%
blue = img[:, :, 0]
green =img[:, :, 1]
red = img[:, :, 2]

cv2_imshow(blue)
cv2_imshow(green)
cv2_imshow(red)

# cv2.imshow
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=415x586 at 0x7F75BEF13B80>
# <PIL.Image.Image image mode=L size=415x586 at 0x7F75BEFA18B0>
# <PIL.Image.Image image mode=L size=415x586 at 0x7F75BEF13B80>

# %%
b, g, r = cv2.split(img)

img_merged = cv2.merge((b, g, r))

cv2_imshow(b)
cv2_imshow(g)
cv2_imshow(r)

cv2_imshow(img_merged)
# Out:
# <PIL.Image.Image image mode=L size=415x586 at 0x7F75BEEF8BB0>
# <PIL.Image.Image image mode=L size=415x586 at 0x7F75BF866220>
# <PIL.Image.Image image mode=L size=415x586 at 0x7F75BF866CD0>
# <PIL.Image.Image image mode=RGB size=415x586 at 0x7F75BEF559D0>

# %%
img = cv2.imread('images/monkey.jpg')
cv2_imshow(img)

resized = cv2.resize(img, None, fx=2, fy=2, interpolation=cv2.INTER_CUBIC)

cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=RGB size=220x330 at 0x7F75BEEF8D30>
# <PIL.Image.Image image mode=RGB size=440x660 at 0x7F75BEEF80D0>
