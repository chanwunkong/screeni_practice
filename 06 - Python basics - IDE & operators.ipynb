# %% [markdown]
# 06 - Python basics - IDE & operators
#
# variable type
# assign
# variable calculate

# %%
print('Hello World')
print('My 2nd line')
# Out:
# Hello World
# My 2nd line

# %%
a = 5
b = 3.0
c = a*b
d = 'hello'
a*d
e = 'world'
d+e
a**b
f = -5
abs(f)
round(a/b)
# Out:
# 2
