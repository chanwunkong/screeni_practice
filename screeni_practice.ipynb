# %% [markdown]
# 01 - Why do you need to learn programming?

# %% [markdown]
# 02 - What is programming?

# %% [markdown]
# 03 - What is command prompt?

# %% [markdown]
# 04 - What is a digital image?

# %% [markdown]
# 05 - What is Python?
